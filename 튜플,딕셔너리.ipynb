# %%
t1=()
t2=(1,)
t3=(1,2,3)
t4=1,2,3
t5=('a','b',('ab'),('cd'))

# %%
import time

def gettime():
  now = time.localtime()
  return now.tm_hour,now.tm_min

hour,min=gettime()
print(f"지금은 {hour}시 {min}분입니다.")
# Out:
# 지금은 5시 45분입니다.

# %%
d,m=divmod(7,3)
print("몫",d)
print("나머지",m)
# Out:
# 몫 2
# 나머지 1

# %%
score=[88,95,70,100,99]
tu = tuple(score)
print(tu)

li=list(tu)
li[0]=100
print(li)
# Out:
# (88, 95, 70, 100, 99)
# [100, 95, 70, 100, 99]
