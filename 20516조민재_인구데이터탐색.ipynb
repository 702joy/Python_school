# %%
# 단계 1: 폰트 설치
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# !apt-get -qq -y install fonts-nanum > /dev/null
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
fm._rebuild()

# %%
# 단계 2: 런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
# 단계 3: 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False
	
# 한글 폰트 설정
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
font_name = fm.FontProperties(fname=path, size=18).get_name()
plt.rc('font', family=font_name)
fm._rebuild()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-85db4ce5-2801-41ef-bf8f-bff2209f8572" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85db4ce5-2801-41ef-bf8f-bff2209f8572">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#파일 오픈
import csv
f = open('population.csv',encoding='cp949')
data = csv.reader(f)
header = next(data)
data=list(data)
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
#헤더 출력, 헤더 길이 확인

# %%
print(header)
print(len(header))
# Out:
# ['행정구역', '2022년08월_계_총인구수', '2022년08월_계_0세', '2022년08월_계_1세', '2022년08월_계_2세', '2022년08월_계_3세', '2022년08월_계_4세', '2022년08월_계_5세', '2022년08월_계_6세', '2022년08월_계_7세', '2022년08월_계_8세', '2022년08월_계_9세', '2022년08월_계_10세', '2022년08월_계_11세', '2022년08월_계_12세', '2022년08월_계_13세', '2022년08월_계_14세', '2022년08월_계_15세', '2022년08월_계_16세', '2022년08월_계_17세', '2022년08월_계_18세', '2022년08월_계_19세', '2022년08월_계_20세', '2022년08월_계_21세', '2022년08월_계_22세', '2022년08월_계_23세', '2022년08월_계_24세', '2022년08월_계_25세', '2022년08월_계_26세', '2022년08월_계_27세', '2022년08월_계_28세', '2022년08월_계_29세', '2022년08월_계_30세', '2022년08월_계_31세', '2022년08월_계_32세', '2022년08월_계_33세', '2022년08월_계_34세', '2022년08월_계_35세', '2022년08월_계_36세', '2022년08월_계_37세', '2022년08월_계_38세', '2022년08월_계_39세', '2022년08월_계_40세', '2022년08월_계_41세', '2022년08월_계_42세', '2022년08월_계_43세', '2022년08월_계_44세', '2022년08월_계_45세', '2022년08월_계_46세', '2022년08월_계_47세', '2022년08월_계_48세', '2022년08월_계_49세', '2022년08월_계_50세', '2022년08월_계_51세', '2022년08월_계_52세', '2022년08월_계_53세', '2022년08
# ...

# %% [markdown]
# ### << 헤더를 이용한 데이터 속성 분석 >>

# %%
#0~100세 총 인구수는 몇번부터 몇번 인덱스에 있을까?

#0~100세 남자 총 인구수는 몇번부터 몇번 인덱스에 있을까?

#0~100세 여자 총 인구수는 몇번부터 몇번 인덱스에 있을까?

# %%
print(header[2],header[102])
print(header[104],header[204])
print(header[206],header[306])
# Out:
# 2022년08월_계_0세 2022년08월_계_100세 이상
# 2022년08월_남_0세 2022년08월_남_100세 이상
# 2022년08월_여_0세 2022년08월_여_100세 이상

# %%
#서울특별시의 연령별 총인구

# %%
print(data[0][2:103])
print(len(data[0][2:103]))
# Out:
# ['40,931', '44,731', '45,511', '49,245', '52,278', '57,054', '64,993', '67,389', '66,458', '69,728', '73,178', '74,211', '70,537', '70,854', '77,007', '76,198', '71,798', '72,776', '81,292', '84,479', '92,605', '109,564', '122,792', '128,581', '140,859', '151,748', '160,960', '163,689', '168,698', '171,640', '169,823', '155,282', '148,124', '142,339', '134,772', '132,666', '132,963', '131,530', '136,684', '145,139', '153,385', '154,158', '153,713', '142,498', '133,753', '136,239', '134,513', '143,303', '155,439', '158,351', '161,030', '169,789', '159,870', '162,879', '151,879', '141,272', '138,092', '141,719', '132,797', '146,195', '136,622', '157,609', '153,686', '140,019', '132,035', '130,199', '120,257', '125,862', '102,156', '95,014', '96,639', '72,168', '81,170', '79,765', '78,781', '77,931', '55,964', '58,999', '55,081', '57,654', '58,697', '46,452', '40,065', '37,030', '31,920', '27,601', '23,645', '20,122', '15,883', '12,847', '10,513', '7,820', '6,636', '5,631', '4,113', '2,
# ...

# %%
#서울특별시의 연령별 남성인구

# %%
print(data[0][104:205])
print(len(data[0][104:205]))
# Out:
# ['21,115', '23,013', '23,458', '25,684', '26,926', '29,115', '33,125', '34,405', '34,172', '35,784', '37,526', '38,155', '36,187', '36,346', '39,714', '39,133', '36,951', '37,434', '41,351', '41,960', '44,702', '52,235', '58,066', '60,160', '65,275', '70,459', '76,652', '79,900', '83,359', '85,408', '84,233', '77,554', '74,448', '71,598', '67,149', '66,039', '66,334', '65,641', '68,565', '72,411', '76,366', '77,515', '75,788', '70,255', '65,891', '67,067', '66,636', '70,769', '76,959', '77,814', '80,135', '84,265', '79,074', '80,112', '74,196', '69,027', '68,882', '69,159', '64,909', '72,003', '66,886', '74,936', '72,363', '66,680', '62,926', '61,067', '56,352', '58,313', '47,491', '44,195', '45,083', '33,318', '37,358', '36,292', '35,845', '35,025', '24,977', '26,545', '24,217', '25,689', '25,859', '20,153', '16,759', '15,117', '12,678', '10,397', '8,569', '6,954', '5,131', '3,951', '3,145', '2,102', '1,649', '1,474', '978', '664', '392', '301', '240', '246', '414']
# 101

# %%
#서울특별시의 연령별 여성인구

# %%
print(data[0][206:307])
print(len(data[0][206:307]))
# Out:
# ['19,816', '21,718', '22,053', '23,561', '25,352', '27,939', '31,868', '32,984', '32,286', '33,944', '35,652', '36,056', '34,350', '34,508', '37,293', '37,065', '34,847', '35,342', '39,941', '42,519', '47,903', '57,329', '64,726', '68,421', '75,584', '81,289', '84,308', '83,789', '85,339', '86,232', '85,590', '77,728', '73,676', '70,741', '67,623', '66,627', '66,629', '65,889', '68,119', '72,728', '77,019', '76,643', '77,925', '72,243', '67,862', '69,172', '67,877', '72,534', '78,480', '80,537', '80,895', '85,524', '80,796', '82,767', '77,683', '72,245', '69,210', '72,560', '67,888', '74,192', '69,736', '82,673', '81,323', '73,339', '69,109', '69,132', '63,905', '67,549', '54,665', '50,819', '51,556', '38,850', '43,812', '43,473', '42,936', '42,906', '30,987', '32,454', '30,864', '31,965', '32,838', '26,299', '23,306', '21,913', '19,242', '17,204', '15,076', '13,168', '10,752', '8,896', '7,368', '5,718', '4,987', '4,157', '3,135', '2,326', '1,504', '1,032', '773', '704', '1,292']
# ...

# %% [markdown]
# ### << 우리 동네 인구 구조 시각화하기 -선그래프 (가로: 나이, 세로: 인구수) >>

# %%
#강남구 연령별 총인구(in 연산자 이용하기)

# %%
for row in data:
  if '서울특별시 강남구 (1168000000)' in row[0]:
    print(row[2:103])
for row in data:
  if '강남구' in row[0]:
    print(row[2:103])
# Out:
# ['1,926', '2,202', '2,262', '2,531', '2,843', '3,268', '3,860', '4,356', '4,725', '5,199', '5,578', '5,964', '5,887', '6,028', '6,617', '6,342', '5,785', '5,735', '6,162', '5,786', '5,539', '6,101', '6,376', '6,122', '6,808', '6,939', '7,463', '7,633', '8,076', '8,474', '8,304', '7,964', '7,647', '7,542', '7,051', '7,140', '7,145', '7,278', '7,794', '8,352', '9,097', '9,635', '9,880', '9,708', '9,317', '9,560', '9,519', '9,884', '10,239', '10,221', '10,401', '10,539', '9,896', '9,154', '8,169', '7,345', '7,018', '7,039', '6,698', '6,955', '6,166', '6,818', '6,813', '6,297', '6,349', '6,387', '5,925', '6,283', '5,236', '5,065', '5,018', '3,599', '4,168', '4,181', '4,118', '4,043', '3,041', '2,925', '2,660', '2,560', '2,475', '2,041', '1,692', '1,515', '1,419', '1,141', '993', '880', '687', '565', '528', '389', '349', '284', '222', '175', '121', '86', '54', '50', '104']
# ...

# %%
#강남구의 연령별 총인구 리스트 만들기

# %%
result=[]
for row in data:
  if '서울특별시 강남구 (1168000000)' in row[0]:
    for i in row[2:103]:
      result.append(i)
print(result)
# Out:
# ['1,926', '2,202', '2,262', '2,531', '2,843', '3,268', '3,860', '4,356', '4,725', '5,199', '5,578', '5,964', '5,887', '6,028', '6,617', '6,342', '5,785', '5,735', '6,162', '5,786', '5,539', '6,101', '6,376', '6,122', '6,808', '6,939', '7,463', '7,633', '8,076', '8,474', '8,304', '7,964', '7,647', '7,542', '7,051', '7,140', '7,145', '7,278', '7,794', '8,352', '9,097', '9,635', '9,880', '9,708', '9,317', '9,560', '9,519', '9,884', '10,239', '10,221', '10,401', '10,539', '9,896', '9,154', '8,169', '7,345', '7,018', '7,039', '6,698', '6,955', '6,166', '6,818', '6,813', '6,297', '6,349', '6,387', '5,925', '6,283', '5,236', '5,065', '5,018', '3,599', '4,168', '4,181', '4,118', '4,043', '3,041', '2,925', '2,660', '2,560', '2,475', '2,041', '1,692', '1,515', '1,419', '1,141', '993', '880', '687', '565', '528', '389', '349', '284', '222', '175', '121', '86', '54', '50', '104']

# %%
# result의 값들을 정수형으로 형변환하기

# %%
result=[]
for row in data:
  if '강남구' in row[0]:
    for i in row[2:103]:
        result.append(int(i))
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0375787df0b4> in <module>
#       3   if '강남구' in row[0]:
#       4     for i in row[2:103]:
# ----> 5         result.append(int(i))
#       6 print(result)
#
# ValueError: invalid literal for int() with base 10: '1,926'

# %% [markdown]
# ###<< 예외처리 try except >>
# try의 코드를 처리 후 에러가 난다면 except의 코드를 실행한다.

# %%
#쉼표를 기준으로 스플릿하여 쉼표 앞에 숫자와 쉼표 뒷 숫자를 연결함

                
print(result)
# Out:
# []

# %%
result=[]
for row in data:
  if '강남구' in row[0]:
    for i in row[2:103]:
      try:
        result.append(int(i))
      except:
        a=i.split(',')[0]+i.split(',')[1]
        result.append(int(a))
print(result)
# Out:
# [1926, 2202, 2262, 2531, 2843, 3268, 3860, 4356, 4725, 5199, 5578, 5964, 5887, 6028, 6617, 6342, 5785, 5735, 6162, 5786, 5539, 6101, 6376, 6122, 6808, 6939, 7463, 7633, 8076, 8474, 8304, 7964, 7647, 7542, 7051, 7140, 7145, 7278, 7794, 8352, 9097, 9635, 9880, 9708, 9317, 9560, 9519, 9884, 10239, 10221, 10401, 10539, 9896, 9154, 8169, 7345, 7018, 7039, 6698, 6955, 6166, 6818, 6813, 6297, 6349, 6387, 5925, 6283, 5236, 5065, 5018, 3599, 4168, 4181, 4118, 4043, 3041, 2925, 2660, 2560, 2475, 2041, 1692, 1515, 1419, 1141, 993, 880, 687, 565, 528, 389, 349, 284, 222, 175, 121, 86, 54, 50, 104]

# %% [markdown]
# ### 그래프로 시각화하기

# %%
import matplotlib.pyplot as plt
plt.plot(result)
plt.show()

# %%
#x축, y축 라벨 추가하기

# %%
plt.plot(result)
plt.xlabel("Age")
plt.ylabel("population")
plt.show()

# %% [markdown]
# ###<< 강남구의 인구구조 출력하는 함수 만들기.(함수이름: population) >>

# %%
def population():
  plt.plot(result)
  plt.xlabel("Age")
  plt.ylabel("population")
  plt.show()

# %%
population()

# %%
population()

# %% [markdown]
# ###<< 인구 구조를 알고 싶은 시군구의 인구구조를 시각화하는 함수 만들기 >>

# %%
#인구 구조가 알고싶은 지역의 이름을 입력 받아서 처리함

def inpopulation():
  result=[]
  city=input("인구 구조가 알고싶은 지역의 이름(시군구 단위)를 입력하세요.: ")
  for row in data:
    if city in row[0]:
      for i in row[2:103]:
        try:
          result.append(int(i))
        except:
          a=i.split(',')[0]+i.split(',')[1]
          result.append(int(a))
      break
  plt.plot(result)
  plt.xlabel("Age")
  plt.ylabel("population")
  plt.show()

# %%
inpopulation()
# Out:
# 인구 구조가 알고싶은 지역의 이름(시군구 단위)를 입력하세요.: 인천

# %%
inpopulation()
# Out:
# 인구 구조가 알고싶은 지역의 이름(시군구 단위)를 입력하세요.: 인천

# %%
def inpopulation():
  result=[]
  city=input("인구 구조가 알고싶은 지역의 이름(시군구 단위)를 입력하세요.: ")
  for row in data:
    if city in row[0]:
      city=row[0]
      for i in row[2:103]:
        try:
          result.append(int(i))
        except:
          a=i.split(',')[0]+i.split(',')[1]
          result.append(int(a))
      break
  plt.plot(result, label=city)
  plt.legend()
  plt.xlabel("Age")
  plt.ylabel("population")
  plt.show()

# %%
inpopulation()
# Out:
# 인구 구조가 알고싶은 지역의 이름(시군구 단위)를 입력하세요.: 인천

# %% [markdown]
# ###<< 특정 지역의 남성, 여성 연령별 비교그래프 그리기 - 가로막대그래프 >>

# %% [markdown]
# ###### 특정 지역 남성의 연령별 막대그래프 그리기

# %%
#0~100세 연령별 남자 인구수 데이터 인덱스 확인하기

# %%
print(header[104],header[204])
# Out:
# 2022년08월_남_0세 2022년08월_남_100세 이상

# %%
#0~100세 강남구 연령별 남자 인구수 확인하기

# %%
result=[]
for row in data:
  if '서울특별시 강남구 (1168000000)' in row[0]:
    for i in row[104:205]:
      result.append(i)
print(result)
# Out:
# ['992', '1,096', '1,172', '1,336', '1,511', '1,615', '1,928', '2,237', '2,499', '2,704', '2,903', '3,147', '3,039', '3,147', '3,441', '3,314', '3,016', '3,017', '3,234', '2,947', '2,764', '3,002', '3,141', '2,882', '3,163', '3,069', '3,403', '3,548', '3,920', '4,132', '3,882', '3,867', '3,635', '3,610', '3,227', '3,307', '3,226', '3,277', '3,526', '3,716', '3,998', '4,378', '4,425', '4,285', '4,264', '4,371', '4,395', '4,589', '4,994', '4,865', '5,189', '5,290', '5,060', '4,655', '4,151', '3,619', '3,582', '3,487', '3,295', '3,450', '3,080', '3,215', '3,154', '2,942', '2,915', '2,939', '2,659', '2,782', '2,379', '2,241', '2,287', '1,663', '1,831', '1,935', '1,934', '1,874', '1,449', '1,438', '1,277', '1,273', '1,224', '957', '797', '743', '620', '477', '414', '306', '229', '178', '165', '106', '83', '66', '39', '45', '23', '17', '12', '10', '18']

# %%
#0~100세 강남구 연령별 남자 인구수 확인하기
result=[]
for row in data:
  if '서울특별시 강남구 (1168000000)' in row[0]:
    for i in row[104:205]:
      result.append(i)
print(result)
# Out:
# ['992', '1,096', '1,172', '1,336', '1,511', '1,615', '1,928', '2,237', '2,499', '2,704', '2,903', '3,147', '3,039', '3,147', '3,441', '3,314', '3,016', '3,017', '3,234', '2,947', '2,764', '3,002', '3,141', '2,882', '3,163', '3,069', '3,403', '3,548', '3,920', '4,132', '3,882', '3,867', '3,635', '3,610', '3,227', '3,307', '3,226', '3,277', '3,526', '3,716', '3,998', '4,378', '4,425', '4,285', '4,264', '4,371', '4,395', '4,589', '4,994', '4,865', '5,189', '5,290', '5,060', '4,655', '4,151', '3,619', '3,582', '3,487', '3,295', '3,450', '3,080', '3,215', '3,154', '2,942', '2,915', '2,939', '2,659', '2,782', '2,379', '2,241', '2,287', '1,663', '1,831', '1,935', '1,934', '1,874', '1,449', '1,438', '1,277', '1,273', '1,224', '957', '797', '743', '620', '477', '414', '306', '229', '178', '165', '106', '83', '66', '39', '45', '23', '17', '12', '10', '18']

# %%
for row in data:
  if '서울특별시 강남구 (1168000000)' in row[0]:
    for i in row[104:205]:
      print(i,end=' ')
# Out:
# 992 1,096 1,172 1,336 1,511 1,615 1,928 2,237 2,499 2,704 2,903 3,147 3,039 3,147 3,441 3,314 3,016 3,017 3,234 2,947 2,764 3,002 3,141 2,882 3,163 3,069 3,403 3,548 3,920 4,132 3,882 3,867 3,635 3,610 3,227 3,307 3,226 3,277 3,526 3,716 3,998 4,378 4,425 4,285 4,264 4,371 4,395 4,589 4,994 4,865 5,189 5,290 5,060 4,655 4,151 3,619 3,582 3,487 3,295 3,450 3,080 3,215 3,154 2,942 2,915 2,939 2,659 2,782 2,379 2,241 2,287 1,663 1,831 1,935 1,934 1,874 1,449 1,438 1,277 1,273 1,224 957 797 743 620 477 414 306 229 178 165 106 83 66 39 45 23 17 12 10 18

# %%
#0~100세 강남구 연령별 남자 인구 리스트 만들기(리스트이름:male)
male = []

        
print(male)
# Out:
# []

# %%
male = []
for row in data:
  if '서울특별시 강남구 (1168000000)' in row[0]:
    for i in row[104:205]:
      male.append(i)
print(male)
# Out:
# ['992', '1,096', '1,172', '1,336', '1,511', '1,615', '1,928', '2,237', '2,499', '2,704', '2,903', '3,147', '3,039', '3,147', '3,441', '3,314', '3,016', '3,017', '3,234', '2,947', '2,764', '3,002', '3,141', '2,882', '3,163', '3,069', '3,403', '3,548', '3,920', '4,132', '3,882', '3,867', '3,635', '3,610', '3,227', '3,307', '3,226', '3,277', '3,526', '3,716', '3,998', '4,378', '4,425', '4,285', '4,264', '4,371', '4,395', '4,589', '4,994', '4,865', '5,189', '5,290', '5,060', '4,655', '4,151', '3,619', '3,582', '3,487', '3,295', '3,450', '3,080', '3,215', '3,154', '2,942', '2,915', '2,939', '2,659', '2,782', '2,379', '2,241', '2,287', '1,663', '1,831', '1,935', '1,934', '1,874', '1,449', '1,438', '1,277', '1,273', '1,224', '957', '797', '743', '620', '477', '414', '306', '229', '178', '165', '106', '83', '66', '39', '45', '23', '17', '12', '10', '18']

# %%
#형변환해서 리스트 만들기
male= []

print(male)
# Out:
# []

# %%
male= []
for row in data:
    if '서울특별시 강남구 (1168000000)' in row[0]:
      for i in row[104:205]:
        try:
          male.append(int(i))
        except:
          a=i.split(',')[0]+i.split(',')[1]
          male.append(int(a))
      break
print(male)
# Out:
# [992, 1096, 1172, 1336, 1511, 1615, 1928, 2237, 2499, 2704, 2903, 3147, 3039, 3147, 3441, 3314, 3016, 3017, 3234, 2947, 2764, 3002, 3141, 2882, 3163, 3069, 3403, 3548, 3920, 4132, 3882, 3867, 3635, 3610, 3227, 3307, 3226, 3277, 3526, 3716, 3998, 4378, 4425, 4285, 4264, 4371, 4395, 4589, 4994, 4865, 5189, 5290, 5060, 4655, 4151, 3619, 3582, 3487, 3295, 3450, 3080, 3215, 3154, 2942, 2915, 2939, 2659, 2782, 2379, 2241, 2287, 1663, 1831, 1935, 1934, 1874, 1449, 1438, 1277, 1273, 1224, 957, 797, 743, 620, 477, 414, 306, 229, 178, 165, 106, 83, 66, 39, 45, 23, 17, 12, 10, 18]

# %%
#세로막대그래프로 시각화하기

# %%
plt.bar(range(101),male)
plt.show()

# %%
#가로막대그래프로 시각화하기

# %%
plt.barh(range(101),male)
plt.show()

# %% [markdown]
# ###### 특정 지역 여성의 연령별 막대그래프 그리기

# %%
#0~100세 연령별 여자 인구수 데이터 인덱스 확인하기

# %%
print(header[206],header[306])
# Out:
# 2022년08월_여_0세 2022년08월_여_100세 이상

# %%
#형변환해서 리스트 만들기
female= []

print(female)
# Out:
# []

# %%
female= []
for row in data:
    if '서울특별시 강남구 (1168000000)' in row[0]:
      for i in row[206:307]:
        try:
          female.append(int(i))
        except:
          a=i.split(',')[0]+i.split(',')[1]
          female.append(int(a))
      break
print(female)
# Out:
# [934, 1106, 1090, 1195, 1332, 1653, 1932, 2119, 2226, 2495, 2675, 2817, 2848, 2881, 3176, 3028, 2769, 2718, 2928, 2839, 2775, 3099, 3235, 3240, 3645, 3870, 4060, 4085, 4156, 4342, 4422, 4097, 4012, 3932, 3824, 3833, 3919, 4001, 4268, 4636, 5099, 5257, 5455, 5423, 5053, 5189, 5124, 5295, 5245, 5356, 5212, 5249, 4836, 4499, 4018, 3726, 3436, 3552, 3403, 3505, 3086, 3603, 3659, 3355, 3434, 3448, 3266, 3501, 2857, 2824, 2731, 1936, 2337, 2246, 2184, 2169, 1592, 1487, 1383, 1287, 1251, 1084, 895, 772, 799, 664, 579, 574, 458, 387, 363, 283, 266, 218, 183, 130, 98, 69, 42, 40, 86]

# %%
#세로막대그래프로 시각화하기

# %%
plt.bar(range(101),female)
plt.show()

# %%
#가로막대그래프로 시각화하기

# %%
plt.barh(range(101),female)
plt.show()

# %%
#강남구 남 녀 연령별 인구수 가로막대그래프로 비교해보기

# %%
plt.barh(range(101),female,color='orange')
plt.barh(range(101),male,color='green')
plt.show()

# %% [markdown]
# ###<< 항아리 모양으로 강남구 남 녀 연령별 인구수 가로막대그래프로 비교해보기>>

# %%
#여성 데이터를 음수로 처리하기
female = []


            
print(female)
# Out:
# []

# %%
female= []
for row in data:
    if '서울특별시 강남구 (1168000000)' in row[0]:
      for i in row[206:307]:
        try:
          female.append((int(i))*-1)
        except:
          a=i.split(',')[0]+i.split(',')[1]
          female.append(int(a)*-1)
      break
print(female)
plt.barh(range(101),female)
plt.show()
# Out:
# [-934, -1106, -1090, -1195, -1332, -1653, -1932, -2119, -2226, -2495, -2675, -2817, -2848, -2881, -3176, -3028, -2769, -2718, -2928, -2839, -2775, -3099, -3235, -3240, -3645, -3870, -4060, -4085, -4156, -4342, -4422, -4097, -4012, -3932, -3824, -3833, -3919, -4001, -4268, -4636, -5099, -5257, -5455, -5423, -5053, -5189, -5124, -5295, -5245, -5356, -5212, -5249, -4836, -4499, -4018, -3726, -3436, -3552, -3403, -3505, -3086, -3603, -3659, -3355, -3434, -3448, -3266, -3501, -2857, -2824, -2731, -1936, -2337, -2246, -2184, -2169, -1592, -1487, -1383, -1287, -1251, -1084, -895, -772, -799, -664, -579, -574, -458, -387, -363, -283, -266, -218, -183, -130, -98, -69, -42, -40, -86]

# %%
#여성, 남성 그래프 합치기.

# %%
plt.barh(range(101),female,color='orange',label="여성")
plt.barh(range(101),male,color='green',label="남성")
plt.legend()
plt.show()

# %%
#남녀 성별 인구 분포 그래프 그리기
def inpopulation2():
  #sa
  d

# %%
def inpopulation2():
  male= []
  female= []
  city=input("궁금한 지역은?: ")
  for row in data:
    if city in row[0]:
      city=row[0]
      for i in row[104:205]:
        try:
          male.append(int(i))
        except:
          a=i.split(',')[0]+i.split(',')[1]
          male.append(int(a))
      for i in row[206:307]:
        try:
          female.append(int(i)*-1)
        except:
          a=i.split(',')[0]+i.split(',')[1]
          female.append(int(a)*-1)
      break
  
  city2=city.split(' ')[1]

  plt.barh(range(101),female,color='orange',label="여성")
  plt.barh(range(101),male,color='green',label="남성")
  plt.title(f'{city2}지역의 남녀 성별 인구 분포',fontsize=10)
  plt.legend()
  plt.show()

# %%
inpopulation2()
# Out:
# 궁금한 지역은?: 종로구

# %%
inpopulation2()
# Out:
# 궁금한 지역은?: 종로구

# %% [markdown]
# ㅍ### << 시도별 18세 인구 수 비교하기 - 막대그래프 >>

# %%
#계_18세 데이터 인덱스 확인하기

# %%
print(header[20])
# Out:
# 2022년08월_계_18세

# %%
#지역별 18세 인구 딕셔너리 만들기
eighteen={}

for row in data:
  try:
    eighteen[row[0]]=int(row[20])
  except:
    a=row[20].split(',')[0]+row[20].split(',')[1]
    eighteen[row[0]]=int(a)
print(eighteen)
print(len(eighteen))
# Out:
# {'서울특별시  (1100000000)': 81292, '서울특별시 종로구 (1111000000)': 1126, '서울특별시 중구 (1114000000)': 760, '서울특별시 용산구 (1117000000)': 1596, '서울특별시 성동구 (1120000000)': 2134, '서울특별시 광진구 (1121500000)': 2685, '서울특별시 동대문구 (1123000000)': 2529, '서울특별시 중랑구 (1126000000)': 2777, '서울특별시 성북구 (1129000000)': 4072, '서울특별시 강북구 (1130500000)': 2281, '서울특별시 도봉구 (1132000000)': 2735, '서울특별시 노원구 (1135000000)': 5745, '서울특별시 은평구 (1138000000)': 4139, '서울특별시 서대문구 (1141000000)': 2521, '서울특별시 마포구 (1144000000)': 2932, '서울특별시 양천구 (1147000000)': 5056, '서울특별시 강서구 (1150000000)': 4637, '서울특별시 구로구 (1153000000)': 2980, '서울특별시 금천구 (1154500000)': 1527, '서울특별시 영등포구 (1156000000)': 2539, '서울특별시 동작구 (1159000000)': 3050, '서울특별시 관악구 (1162000000)': 3157, '서울특별시 서초구 (1165000000)': 4375, '서울특별시 강남구 (1168000000)': 6162, '서울특별시 송파구 (1171000000)': 5858, '서울특별시 강동구 (1174000000)': 3919, '부산광역시  (2600000000)': 27421, '부산광역시 중구 (2611000000)': 210, '부산광역시 서구 (2614000000)': 806, '부산광역시 동구 (2617000000)': 538, '부산광역시 영도구 (2620000000)': 799, '부산광역시 부산진구 (26
# ...

# %%
print(len(eighteen))
# Out:
# 292

# %%
#시, 도 만 추출하기 1단계
for row in data:
  if len(row[0].split('  '))==2:
    print(row[0])
# Out:
# 서울특별시  (1100000000)
# 부산광역시  (2600000000)
# 대구광역시  (2700000000)
# 인천광역시  (2800000000)
# 광주광역시  (2900000000)
# 대전광역시  (3000000000)
# 울산광역시  (3100000000)
# 세종특별자치시  (3600000000)
# 경기도  (4100000000)
# 북부출장소  (4110500000)
# 강원도  (4200000000)
# 동해출장소  (4210500000)
# 충청북도  (4300000000)
# 충청남도  (4400000000)
# 전라북도  (4500000000)
# 전라남도  (4600000000)
# 경상북도  (4700000000)
# 경상남도  (4800000000)
# 제주특별자치도  (5000000000)

# %%
#시, 도 만 추출하기 2단계
for row in data:
  if len(row[0].split())==2 & row[0].split()[0] in "출장소":
    print(row[0])
# Out:
# 서울특별시  (1100000000)
# 부산광역시  (2600000000)
# 대구광역시  (2700000000)
# 인천광역시  (2800000000)
# 광주광역시  (2900000000)
# 대전광역시  (3000000000)
# 울산광역시  (3100000000)
# 세종특별자치시  (3600000000)
# 경기도  (4100000000)
# 강원도  (4200000000)
# 충청북도  (4300000000)
# 충청남도  (4400000000)
# 전라북도  (4500000000)
# 전라남도  (4600000000)
# 경상북도  (4700000000)
# 경상남도  (4800000000)
# 제주특별자치도  (5000000000)

# %%
for row in data:
  if len(row[0].split())==2 and row[0].split()[0] not in ["츌장소"]:
    print(row[0])
# Out:
# 서울특별시  (1100000000)
# 부산광역시  (2600000000)
# 대구광역시  (2700000000)
# 인천광역시  (2800000000)
# 광주광역시  (2900000000)
# 대전광역시  (3000000000)
# 울산광역시  (3100000000)
# 세종특별자치시  (3600000000)
# 경기도  (4100000000)
# 북부출장소  (4110500000)
# 강원도  (4200000000)
# 동해출장소  (4210500000)
# 충청북도  (4300000000)
# 충청남도  (4400000000)
# 전라북도  (4500000000)
# 전라남도  (4600000000)
# 경상북도  (4700000000)
# 경상남도  (4800000000)
# 제주특별자치도  (5000000000)

# %%
for row in data:
  if len(row[0].split())==2 and row[0].split()[0][-1] in ["시","도"]:
    print(row[0])
# Out:
# 서울특별시  (1100000000)
# 부산광역시  (2600000000)
# 대구광역시  (2700000000)
# 인천광역시  (2800000000)
# 광주광역시  (2900000000)
# 대전광역시  (3000000000)
# 울산광역시  (3100000000)
# 세종특별자치시  (3600000000)
# 경기도  (4100000000)
# 강원도  (4200000000)
# 충청북도  (4300000000)
# 충청남도  (4400000000)
# 전라북도  (4500000000)
# 전라남도  (4600000000)
# 경상북도  (4700000000)
# 경상남도  (4800000000)
# 제주특별자치도  (5000000000)

# %%
#시도별 18세 인구 딕셔너리 만들기
eighteen={}

for row in data:
  if len(row[0].split())==2 and row[0].split()[0][-1] in ["시","도"]:
      city=row[0].split()[0]
      try:
        eighteen[city]=int(row[20])
      except:
        a=row[20].split(',')[0]+row[20].split(',')[1]
        eighteen[city]=int(a)

# %%
#딕셔너리 확인해보기
# Out:
# {'서울특별시': 81292,
#  '부산광역시': 27421,
#  '대구광역시': 23234,
#  '인천광역시': 27503,
#  '광주광역시': 15787,
#  '대전광역시': 15020,
#  '울산광역시': 10803,
#  '세종특별자치시': 3975,
#  '경기도': 134543,
#  '강원도': 14092,
#  '충청북도': 14985,
#  '충청남도': 19924,
#  '전라북도': 17460,
#  '전라남도': 16847,
#  '경상북도': 22474,
#  '경상남도': 31579,
#  '제주특별자치도': 6885}

# %%
eighteen
# Out:
# {'서울특별시': 81292,
#  '부산광역시': 27421,
#  '대구광역시': 23234,
#  '인천광역시': 27503,
#  '광주광역시': 15787,
#  '대전광역시': 15020,
#  '울산광역시': 10803,
#  '세종특별자치시': 3975,
#  '경기도': 134543,
#  '강원도': 14092,
#  '충청북도': 14985,
#  '충청남도': 19924,
#  '전라북도': 17460,
#  '전라남도': 16847,
#  '경상북도': 22474,
#  '경상남도': 31579,
#  '제주특별자치도': 6885}

# %%
#세로막대로 시각화하기

# %%
# 지역별 나이 비교 함수 만들기
def population2():

# %%
population2()

# %% [markdown]
# ### 해당 나이의 인덱스 찾기
# 0세 -> 2
#
# 1세 -> 3
#
# ...
#
# 18세 -> 20
#
#
# n세 -> n+2

# %%
### 지역별 나이 비교 함수 만들기
def inpopulation3():

# %%
inpopulation3()
