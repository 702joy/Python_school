# %%
import matplotlib.font_manager as fm

0!apt-get -qq -y install fonts-nanum > /dev/null
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
fm._rebuild()

# %%
import os
os.kill(os.getpid(), 9)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
mpl.rcParams['axes.unicode_minus'] = False

# %%
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
font_name = fm.FontProperties(fname=path, size=18).get_name()
plt.rc('font', family=font_name)
fm._rebuild()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ba5af883-8608-459b-b249-6089b002c49d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba5af883-8608-459b-b249-6089b002c49d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather.csv to weather.csv

# %%
import csv
f=open('weather.csv',encoding='cp949')
data=csv.reader(f)
header=next(data)
data=list(data)
f.close()

# %%
print(len(data))
# Out:
# 35651

# %%
for row in data[:3]:
  print(row[0])
# Out:
# 1921-01-01
# 1921-01-02
# 1921-01-03

# %%
avg=[]
years=[1960]
sum=0
days=0
for row in data:
  if int(row[0].split('-')[0])==years[-1]:
    sum+=float(row[1])
    days+=1
  elif int(row[0].split('-')[0])>years[-1]:
    avg.append(sum/days)
    if int(row[0].split('-')[0])==2021:
      break 
    else:
      years.append(years[-1]+1)
      sum = float(row[1])
      days = 1
plt.figure(figsize=(15,4))
plt.xlabel('연도')
plt.ylabel('기온')
plt.plot(years,avg,'red')
plt.title('1960~2020년 의평균기온 그래프')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.hist([1,1,1,2,3,4,4,5,6,6,7,8,10])
plt.show()

# %%
result=[]

for row in data:
  if row[2] != '':
    result.append(float(row[2]))
plt.hist(result,bins=100)
plt.show()

# %%
aug = []
jan = []
for row in data:
  month=row[0].split('-')[1]
  if row[2] != '':
    if month == '08':
      aug.append(float(row[2]))
    if month == '01':
      jan.append(float(row[2]))
plt.hist(aug,bins=100,color='red',label='aug')
plt.hist(jan,bins=100,color='blue',label='jan')
plt.legend()
plt.show()

# %%
import random
result=[]

for i in range(15):
  result.append(random.randint(1,1000))
print(sorted(result))
result.sort()
plt.boxplot(result)
plt.show()
# Out:
# [180, 195, 210, 246, 322, 374, 487, 607, 652, 691, 816, 845, 902, 934, 956]

# %%
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
plt.boxplot(aug,jan)
plt.show()

# %%
plt.boxplot([aug,jan])
plt.show()

# %%
month=[]
for i in range(12):
  month.append([])
for row in data:
  if row[2] != '':
      month[int(row[0].split('-')[1])-1].append(float(row[2]))
plt.boxplot(month)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
days=[]
for i in range(31):
  days.append([])
for row in data:
  if row[2] != '' and row[0].split('-')[1] == '08':
      days[int(row[0].split('-')[2])-1].append(float(row[2]))
plt.style.use('ggplot')
plt.figure(figsize = (10,5))
plt.boxplot(days,showfliers=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
